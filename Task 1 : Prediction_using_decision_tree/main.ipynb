# %% [markdown]
# # Prediction Using Decision Tree Algorithm

# %%
# ignore the warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing The Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
#matplotlib inline

# %% [markdown]
# ## Loading The .csv Dataset

# %%
df = pd.read_csv('iris.csv')
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# ## Inspecting The Dataset

# %% [markdown]
# ### 1. Getting The Dataset Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# ### 2. Visualizing The Dataset

# %%
sns.pairplot(df, hue='Species')

# %% [markdown]
# #### Flower with small petal width and length is Iris-setosa.

# %% [markdown]
# #### Flower with medium petal length and width is Iris-versicolor

# %% [markdown]
# #### Flower with larger petal width and length is Iris-virginica

# %% [markdown]
# ## Spliting The Dataset Into Test And Train Data

# %%
x = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']].values
y = df[['Species']].values
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Fitting The Train Data Into Decision Tree Model And Predicting The Test Data

# %%
model = DecisionTreeClassifier()
model.fit(x_train, y_train)

predict = model.predict(x_test)

# %% [markdown]
# ## Checking The Accuracy

# %%
accuracy = accuracy_score(y_test, predict)
accuracy
# Out:
# 1.0

# %% [markdown]
# ## Giving A New Input And Checking The Output

# %%
new = []
sepalLength = input('Enter the Sepal Length (max range-8cm): ')
new.append(sepalLength)
sepalWidth = input('Enter the Sepal Width (max range-4.5cm): ')
new.append(sepalWidth)
petalLength = input('Enter the Petal Length (max range-7cm): ')
new.append(petalLength)
petalWidth = input('Enter the Petal Width (max range-2.5cm): ')
new.append(petalWidth)
new_array = [new]
output_prediction = model.predict(new_array)
# Out:
# Enter the Sepal Length (max range-8cm): 5.8
# Enter the Sepal Width (max range-4.5cm): 2.8
# Enter the Petal Length (max range-7cm): 5.2
# Enter the Petal Width (max range-2.5cm): 2.6

# %%
species = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
for item in range(len(output_prediction)):
    print(output_prediction[item])
# Out:
# Iris-virginica

# %% [markdown]
# ## Visualizing The Tree

# %%
fig = plt.figure(figsize=(25,20))
figure = tree.plot_tree(model,
                       feature_names=(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']),
                       class_names=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'],
                       rounded=True,
                       filled=True)

# %% [markdown]
# #### Petal Width less than 0.8cm is Iris-setosa

# %% [markdown]
# #### Generally Petal Width less than 1.75cm and Petal Length less than 4.85cm belongs to Iris-virginica

# %% [markdown]
# #### Generally Petal Width less than 1.75cm and Petal Length less than 4.95cm belongs to Iris-versicolor

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### 1. Flower with small petal width and length and medium to small sepal length is Iris-setosa

# %% [markdown]
# ### 2. Flower with medium petal width and length and medium sepal length is Iris-versicolor

# %% [markdown]
# ### 3. Flower with large petal width and length and high to medium sepal length is Iris-virginica
